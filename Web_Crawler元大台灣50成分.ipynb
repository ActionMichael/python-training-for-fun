# %% [markdown]
# <a href="https://colab.research.google.com/github/ActionMichael/python-training-for-fun/blob/master/Web_Crawler%E5%85%83%E5%A4%A7%E5%8F%B0%E7%81%A350%E6%88%90%E5%88%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://www.yuantaetfs.com/#/FundWeights/1066"

# %%
df = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0a00aa54acda> in <module>()
# ----> 1 df = pd.read_html(url)
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913             break
#     914     else:
# --> 915         raise retained
#     916
#     917     ret = []
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
# ...

# %% [markdown]
# ![alt text](https://github.com/ActionMichael/python-training-for-fun/blob/master/001.jpg)
# ![alt text](https://https://github.com/ActionMichael/python-training-for-fun/blob/master/002.jpg)
#
# 用上述方式找到表格所藏的真實位置，針對不同步資料傳輸有用

# %%
url = "https://www.yuantaetfs.com/api/StkWeights?date=&fundid=1066"

# %%
df = pd.read_json(url)

# %%
df
# Out:
#     code  ym  ... weights        qty
# 0   1101 NaN  ...    1.18   24122178
# 1   1102 NaN  ...    0.56   11592895
# 2   1216 NaN  ...    1.95   23961990
# 3   1301 NaN  ...    2.26   24339985
# 4   1303 NaN  ...    1.89   28221709
# 5   1326 NaN  ...    1.42   17112368
# 6   1402 NaN  ...    0.55   19609598
# 7   2002 NaN  ...    1.45   61642708
# 8   2105 NaN  ...    0.35    9163574
# 9   2207 NaN  ...    0.94    1593808
# 10  2301 NaN  ...    0.55   10629712
# 11  2303 NaN  ...    0.95   54966811
# 12  2308 NaN  ...    1.62   10797687
# 13  2317 NaN  ...    5.22   59647843
# 14  2327 NaN  ...    0.67    1971884
# 15  2330 NaN  ...   40.72  120026043
# 16  2357 NaN  ...    0.87    3525002
# 17  2382 NaN  ...    0.99   13298881
# 18  2395 NaN  ...    0.57    1862373
# 19  2408 NaN  ...    0.27    4031778
# 20  2412 NaN  ...    2.54   19011085
# 21  2454 NaN  ...    3.08    7382833
# 22  2474 NaN  ...    0.93    3689424
# 23  2633 NaN  ...    0.37   10414837
# ...
